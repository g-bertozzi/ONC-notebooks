# %% [markdown]
# # Pre Req Doc

# %% [markdown]
# Instructions on how to set up deepnote accounts and duplicate the project.

# %% [markdown]
# Just ensure the link to the project is linked to the student version of the project.

# %% [markdown]
# I've also uploaded the file into the project files on the left.
